# %% [markdown]
# # Initial Exploration of the dataset

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import os.path
import pickle

# %% [markdown]
# ## Constants

# %%
dataset_csv = "data_20240725.csv"
dataset_pickle = "data_20240725.pickle"

# %%
if not os.path.isfile(dataset_pickle):
    data = pd.read_csv(dataset_csv)
else:
    data = pickle.loads(open(dataset_pickle, "rb"))

# %%
data.columns
# data.Class.value_counts()
# Out:
# Index(['YearStart', 'YearEnd', 'LocationDesc', 'Class', 'Topic', 'Question',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Alt',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Stratification1',
#        'Geolocation', 'ClassID', 'TopicID', 'QuestionID', 'LocationID',
#        'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')

# %%
data.Data_Value_Alt.value_counts()

data = data.drop("Data_Value_Alt", axis=1)
data
# Out:
#         YearStart  YearEnd   LocationDesc  \
# 0            2022     2022   Pennsylvania
# 1            2022     2022   South Dakota
# 2            2022     2022          Idaho
# 3            2022     2022       Maryland
# 4            2022     2022      Wisconsin
# ...           ...      ...            ...
# 284137       2016     2016      Wisconsin
# 284138       2017     2017        Wyoming
# 284139       2015     2015        Wyoming
# 284140       2019     2019  West Virginia
# 284141       2015     2015        Wyoming
#
#                                       Class  \
# 0                             Mental Health
# 1                             Mental Health
# 2                             Mental Health
# 3                             Mental Health
# 4                             Mental Health
# ...                                     ...
# 284137              Screenings and Vaccines
# 284138                       Overall Health
# 284139                    Cognitive Decline
# ...

# %%
data[data.isna()][["Data_Value", "Low_Confidence_Limit"]]
# data
# Out:
#         Data_Value  Low_Confidence_Limit
# 0              NaN                   NaN
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN                   NaN
# 4              NaN                   NaN
# ...            ...                   ...
# 284137         NaN                   NaN
# 284138         NaN                   NaN
# 284139         NaN                   NaN
# 284140         NaN                   NaN
# 284141         NaN                   NaN
#
# [284142 rows x 2 columns]

# %%
# data[(data.Data_Value != data.Data_Value_Alt) & ~(data.Data_Value.isna())][["Data_Value_Alt", "Data_Value"]]
data.Topic.value_counts()
# Out:
# Topic
# Frequent mental distress                                                                                  11092
# Current smoking                                                                                           11092
# Influenza vaccine within past year                                                                        11092
# Lifetime diagnosis of depression                                                                          11092
# Obesity                                                                                                   11092
# Physically unhealthy days (mean number of days)                                                           11092
# No leisure-time physical activity within past month                                                       11092
# Self-rated health (good to excellent health)                                                              11091
# ...

# %%
pickle.dump(data, open(dataset_pickle, "wb"))
